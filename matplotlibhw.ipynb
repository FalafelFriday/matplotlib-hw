# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np


file = "city_data.csv"
filee = "ride_data.csv"
cityd=pd.read_csv(file)
rided=pd.read_csv(filee)
df=pd.merge(rided,cityd,on="city",how="left")
df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2018-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2018-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %%
uct=df[df["type"]=="Urban"].groupby(df["city"])
rct=df[df["type"]=="Rural"].groupby(df["city"])
sct=df[df["type"]=="Suburban"].groupby(df["city"])

# %%
xau=uct["ride_id"].count()
yau=uct["fare"].mean()
zau=uct["driver_count"].mean()

xar=rct["ride_id"].count()
yar=rct["fare"].mean()
zar=rct["driver_count"].mean()

xas=sct["ride_id"].count()
yas=sct["fare"].mean()
zas=sct["driver_count"].mean()
plt.scatter(xau, yau, marker="o", facecolors="coral", edgecolors="black",
            s=zau, alpha=0.75)
plt.scatter(xar, yar, marker="o", facecolors="gold", edgecolors="black",
            s=zar, alpha=0.75)
plt.scatter(xas, yas, marker="o", facecolors="skyblue", edgecolors="black",
            s=zas, alpha=0.75)
plt.xlabel("Total number of rides per city")
plt.ylabel("Average fare")
plt.title("Pyber Ride Sharing Data (2016)")
plt.grid
# Out:
# <function matplotlib.pyplot.grid(b=None, which='major', axis='both', **kwargs)>

# %%
qldf=df.groupby('type')
fs=qldf['fare'].sum()

# %%
labels=["Rural","Suburban","Urban"]
explode=[0,0,0.1]
sizes=fs
colors=["gold","skyblue","coral"]
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
plt.title("% of total fares by city type")
#plt.savefig("Desktop/TotalFaresbyCityType.png")
# Out:
# Text(0.5, 1.0, '% of total fares by city type')

# %%
tr=qldf['ride_id'].count()

# %%
labels=["Rural","Suburban","Urban"]
explode=[0,0,0.1]
sizes=tr
colors=["gold","skyblue","coral"]
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
plt.title("% Percent of rides by city type")
#plt.savefig("Desktop/TotalRidesbyCityType.png")
# Out:
# Text(0.5, 1.0, '% Percent of rides by city type')

# %%
ldf=cityd.groupby('type')
dr=ldf['driver_count'].sum()

# %%
labels=["Rural","Suburban","Urban"]
explode=[0,0,0.1]
sizes=dr
colors=["gold","skyblue","coral"]
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
plt.title("% of drivers by city type")
#plt.savefig("Desktop/TotalDriversbyCityType.png")
# Out:
# Text(0.5, 1.0, '% of drivers by city type')
